# %% [markdown]
# imports

# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# Reading the Data

# %%
df = pd.read_csv('D:\DataAnalystPortfolioProjects\Project 3\movies.csv')

# %% [markdown]
# Data Sample

# %%
df
# Out:
#           budget                                 company country  \
# 0      8000000.0           Columbia Pictures Corporation     USA
# 1      6000000.0                      Paramount Pictures     USA
# 2     15000000.0                      Paramount Pictures     USA
# 3     18500000.0  Twentieth Century Fox Film Corporation     USA
# 4      9000000.0                    Walt Disney Pictures     USA
# ...          ...                                     ...     ...
# 6815         0.0                Fox Searchlight Pictures      UK
# 6816         0.0                Siempre Viva Productions     USA
# 6817   3500000.0                  Warner Bros. Animation     USA
# 6818         0.0                     Borderline Presents     USA
# 6819         0.0               Les Productions du Tr�sor  France
#
#              director      genre        gross                            name  \
# 0          Rob Reiner  Adventure   52287414.0                     Stand by Me
# ...

# %% [markdown]
# Looking for Missing Data

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %% [markdown]
# Looking at the data types of our columns

# %%
df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %% [markdown]
# Changing the data type of columns budget and gross from float to int64

# %%
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#         budget                                 company country  \
# 0      8000000           Columbia Pictures Corporation     USA
# 1      6000000                      Paramount Pictures     USA
# 2     15000000                      Paramount Pictures     USA
# 3     18500000  Twentieth Century Fox Film Corporation     USA
# 4      9000000                    Walt Disney Pictures     USA
# ...        ...                                     ...     ...
# 6815         0                Fox Searchlight Pictures      UK
# 6816         0                Siempre Viva Productions     USA
# 6817   3500000                  Warner Bros. Animation     USA
# 6818         0                     Borderline Presents     USA
# 6819         0               Les Productions du Tr�sor  France
#
#              director      genre      gross                            name  \
# 0          Rob Reiner  Adventure   52287414                     Stand by Me
# ...

# %% [markdown]
# Creating Correct year Column

# %%
df['yearcorrect'] = df['released'].astype(str).str[:4]
df
# Out:
#         budget                                 company country  \
# 0      8000000           Columbia Pictures Corporation     USA
# 1      6000000                      Paramount Pictures     USA
# 2     15000000                      Paramount Pictures     USA
# 3     18500000  Twentieth Century Fox Film Corporation     USA
# 4      9000000                    Walt Disney Pictures     USA
# ...        ...                                     ...     ...
# 6815         0                Fox Searchlight Pictures      UK
# 6816         0                Siempre Viva Productions     USA
# 6817   3500000                  Warner Bros. Animation     USA
# 6818         0                     Borderline Presents     USA
# 6819         0               Les Productions du Tr�sor  France
#
#              director      genre      gross                            name  \
# 0          Rob Reiner  Adventure   52287414                     Stand by Me
# ...

# %% [markdown]
# Sorting the Table according to the gross column

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
pd.set_option('display.max_rows', None) #Sets maximum rows options in pandas such that all the rows are displayed

# %% [markdown]
# Droping any Duplicates

# %%
df['company'].drop_duplicates().sort_values(ascending = False)
# Out:
# 5288                                          micro_scope
# 3486                                             i5 Films
# 6084                                                 erbp
# 3225                                       double A Films
# 2707                          Zucker Brothers Productions
# 1495                                   Zeta Entertainment
# 5905                                 Zentropa Productions
# 5917                        Zentropa International Norway
# 3126                              Zentropa Entertainments
# 329                                  Zenith Entertainment
# 4710                                      Zazen Produ��es
# 542                              Zanuck/Brown Productions
# 698                                   Zanuck Company, The
# 499                           Zacharias-Buhai Productions
# 4687                           Young Hannibal Productions
# 5084                                          Yellow Bird
# ...

# %% [markdown]
# Assumptions:(w.r.t. to Gross(Revenue)):
#
# 1.Budget has high Correlation.
#
# 2.Company has high Correlation.

# %% [markdown]
# Scatter Plot of Budget Vs Gross Revenue

# %%
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Revenue')
plt.xlabel('Budget')
plt.ylabel('Gross Revenue')
plt.show()

# %% [markdown]
# Plotting Budget Vs Gross Revenue using Seaborn

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'red'}, line_kws={'color':'green'})
plt.show()

# %% [markdown]
# Let's look at different Correlations

# %%
df.corr(method='pearson')
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000

# %%
df.corr(method='kendall')
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.523459  0.164816 -0.019526  0.451137  0.214114
# gross    0.523459  1.000000  0.139270  0.033163  0.479772  0.098585
# runtime  0.164816  0.139270  1.000000  0.282068  0.195640  0.073785
# score   -0.019526  0.033163  0.282068  1.000000  0.272967  0.070451
# votes    0.451137  0.479772  0.195640  0.272967  1.000000  0.339625
# year     0.214114  0.098585  0.073785  0.070451  0.339625  1.000000

# %%
df.corr(method='spearman')
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.698639  0.231672 -0.027868  0.616419  0.300553
# gross    0.698639  1.000000  0.202905  0.045582  0.667869  0.139467
# runtime  0.231672  0.202905  1.000000  0.398840  0.287150  0.107902
# score   -0.027868  0.045582  0.398840  1.000000  0.392199  0.103598
# votes    0.616419  0.667869  0.287150  0.392199  1.000000  0.485588
# year     0.300553  0.139467  0.107902  0.103598  0.485588  1.000000

# %% [markdown]
# High Correlation between budget and gross can be seen from the matrix

# %% [markdown]
# Creating a heatmap using correlation matrix

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %% [markdown]
# Converting the non numeric features of movies to numeric(Categoric)

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#          budget  company  country  director  genre      gross  name  rating  \
# 6380  245000000     1428       54      1037      0  936662225  4679       7
# 5061  237000000     2062       53      1066      0  760507625   501       7
# 2420  200000000     2062       54      1066      6  658672302  6177       7
# 6391  150000000     2085       54       466      0  652270625  2721       7
# 5723  220000000     1491       54      1412      0  623357910  4995       7
#
#       released  runtime  score  star    votes  writer  year  yearcorrect
# 6380      2290      136    8.1   475   687192    2356  2015           29
# 5061      1800      162    7.8  2084   954412    1629  2009           23
# 2420       910      194    7.8  1444   862554    1629  1997           11
# 6391      2247      124    7.0   404   469200    3310  2015           29
# 5723      1987      143    8.1  2001  1064633    2145  2012           26

# %% [markdown]
# Correlation of non numeric data

# %%
df_numerized.corr()
# Out:
#                budget   company   country  director     genre     gross  \
# budget       1.000000  0.187205  0.137635  0.011602 -0.346794  0.712196
# company      0.187205  1.000000  0.107950  0.004320 -0.068330  0.187220
# country      0.137635  0.107950  1.000000  0.003699 -0.042793  0.149988
# director     0.011602  0.004320  0.003699  1.000000 -0.027669 -0.011429
# genre       -0.346794 -0.068330 -0.042793 -0.027669  1.000000 -0.242676
# gross        0.712196  0.187220  0.149988 -0.011429 -0.242676  1.000000
# name         0.028712  0.018098  0.025020  0.001906  0.018062  0.022768
# rating      -0.119660 -0.062250  0.057979  0.021926  0.100960 -0.135538
# released     0.276635  0.027898 -0.062609  0.001440 -0.039179  0.178564
# runtime      0.268226  0.033058 -0.081796  0.026779 -0.041357  0.224579
# score        0.042145 -0.010426 -0.174414  0.017130  0.056234  0.165693
# star        -0.015062 -0.003160 -0.014569  0.039813  0.008140  0.008381
# ...

# %% [markdown]
# Heatmap using the correlation matrix

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for All the Movie Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %% [markdown]
# Unstacking the matrix into pairs

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# budget       budget         1.000000
#              company        0.187205
#              country        0.137635
#              director       0.011602
#              genre         -0.346794
#              gross          0.712196
#              name           0.028712
#              rating        -0.119660
#              released       0.276635
#              runtime        0.268226
#              score          0.042145
#              star          -0.015062
#              votes          0.503924
#              writer        -0.015611
#              year           0.291009
#              yearcorrect    0.274820
# company      budget         0.187205
#              company        1.000000
#              country        0.107950
#              director       0.004320
#              genre         -0.068330
#              gross          0.187220
#              name           0.018098
#              rating        -0.062250
#              released       0.027898
# ...

# %% [markdown]
# Sorting the pairs

# %%
sorted_pairs = corr_pairs.sort_values(ascending=False)

# %%
sorted_pairs
# Out:
# budget       budget         1.000000
# company      company        1.000000
# year         year           1.000000
# writer       writer         1.000000
# votes        votes          1.000000
# star         star           1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# released     released       1.000000
# rating       rating         1.000000
# name         name           1.000000
# gross        gross          1.000000
# genre        genre          1.000000
# director     director       1.000000
# country      country        1.000000
# yearcorrect  yearcorrect    1.000000
#              released       0.999389
# released     yearcorrect    0.999389
# yearcorrect  year           0.996229
# year         yearcorrect    0.996229
#              released       0.996187
# released     year           0.996187
# budget       gross          0.712196
# gross        budget         0.712196
#              votes          0.662457
# ...

# %% [markdown]
# Taking the pairs with high correlation

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# budget       budget         1.000000
# company      company        1.000000
# year         year           1.000000
# writer       writer         1.000000
# votes        votes          1.000000
# star         star           1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# released     released       1.000000
# rating       rating         1.000000
# name         name           1.000000
# gross        gross          1.000000
# genre        genre          1.000000
# director     director       1.000000
# country      country        1.000000
# yearcorrect  yearcorrect    1.000000
#              released       0.999389
# released     yearcorrect    0.999389
# yearcorrect  year           0.996229
# year         yearcorrect    0.996229
#              released       0.996187
# released     year           0.996187
# budget       gross          0.712196
# gross        budget         0.712196
#              votes          0.662457
# ...

# %% [markdown]
# Conclusion:
#
# budget and votes have the highest correlation to gross revenue
#
# Our assumption of high correlation between gross and company was wrong
